# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
import pandas as pd
from univariate import Univ

# %%
quan,qual=Univ.QuanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
import importlib
import univariate
importlib.reload(univariate)
from univariate import Univ

# %%
Descriptive = Univ.percentile(dataset)
Descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
# 0%          1      40.89       37.0       50.0       50.0      51.21
# Q1:25    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100    215       89.4       97.7       91.0       98.0      77.89
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0
# 0%           200000.0
# Q1:25        240000.0
# Q2:50        265000.0
# Q3:75        300000.0
# Q4:100       940000.0

# %%
Descriptive = Univ.IQR(dataset)
Descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# 0%           1      40.89       37.0       50.0       50.0      51.21
# Q1:25     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75    161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100     215       89.4       97.7       91.0       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5IQR   160.5      22.65      18.15       16.5      35.25     12.465
# lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# greater  322.0      98.35      91.15       88.5     118.75      78.72
#
#                 salary
# Mean     288655.405405
# ...

# %%
Lesser, Greater = Univ.findoutlier(dataset)

# %%
Lesser
# Out:
# ['hsc_p']

# %%
Greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
Lesser1, Greater1 = Univ.handlingoutlier(dataset)
print(Lesser1)
print(Greater1)
# Out:
# []
# []

# %%
freqTable = Univ.AllfreqTable("ssc_p", dataset)
freqTable
# Out:
#      Column_name  Frequency  Relative_Frequency      cumsum
# 0          62.00         11            5.116279    5.116279
# 1          63.00         10            4.651163    9.767442
# 2          67.00          9            4.186047   13.953488
# 3          52.00          9            4.186047   18.139535
# 4          73.00          9            4.186047   22.325581
# ..           ...        ...                 ...         ...
# 98         69.70          1            0.465116   98.139535
# 99         80.92          1            0.465116   98.604651
# 100        83.00          1            0.465116   99.069767
# 101        86.50          1            0.465116   99.534884
# 102        80.60          1            0.465116  100.000000
#
# [103 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.histplot(dataset["ssc_p"], bins=10, kde=True)

plt.title("Distribution of SSC Percentage")
plt.xlabel("SSC Percentage")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.bar(freqTable["Column_name"], freqTable["Relative_Frequency"])
plt.xlabel("SSC Percentage")
plt.ylabel("Relative Frequency (%)")
plt.title("Relative Frequency Distribution")
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.bar(freqTable["Column_name"], freqTable["Frequency"])
plt.xlabel("SSC Percentage")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of SSC Percentage")
plt.xticks(rotation=90)
plt.show()
